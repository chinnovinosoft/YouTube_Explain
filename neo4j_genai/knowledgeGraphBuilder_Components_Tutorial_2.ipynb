# %%
import os
os.environ["OPENAI_API_KEY"]=""

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
from pathlib import Path
import neo4j
from neo4j_graphrag.experimental.components.pdf_loader import PdfLoader
from neo4j_graphrag.experimental.components.text_splitters.fixed_size_splitter import (
    FixedSizeSplitter,
)
from neo4j_graphrag.experimental.components.types import TextChunks
from neo4j_graphrag.experimental.components.embedder import TextChunkEmbedder
from neo4j_graphrag.embeddings.openai import OpenAIEmbeddings
from neo4j_graphrag.experimental.components.lexical_graph import (
    LexicalGraphBuilder,
)
from neo4j_graphrag.experimental.components.types import (
    GraphResult,
    LexicalGraphConfig,
    TextChunk,
    TextChunks,
    DocumentInfo,
)
from neo4j_graphrag.experimental.components.kg_writer import Neo4jWriter
from neo4j_graphrag.experimental.components.types import Neo4jGraph
from neo4j_graphrag.experimental.components.neo4j_reader import Neo4jChunkReader
from neo4j_graphrag.experimental.components.schema import (
    SchemaBuilder,
    SchemaEntity,
    SchemaProperty,
    SchemaRelation,
)
from neo4j_graphrag.experimental.components.entity_relation_extractor import (
    LLMEntityRelationExtractor,
)
from neo4j_graphrag.experimental.components.types import SchemaEnforcementMode
from neo4j_graphrag.llm import OpenAILLM

# %%
file_path = "Harry Potter and the Chamber of Secrets Summary.pdf"

# %%
loader = PdfLoader()
document = await loader.run(filepath=file_path)

# %%
print(document.text[:200])
# Out:
# Harry Potter and the Chamber of
# Secrets Full Book Summary
# Harry Potter and the Chamber of Secrets begins when Harry is spending a
# miserable summer with his only remaining family, the Dursleys. Durin

# %%
print(document.document_info)
# Out:
# path='Harry Potter and the Chamber of Secrets Summary.pdf' metadata=None uid='0065aa4e-92ef-4da7-b548-8f04fbb1054a'

# %%
splitter = FixedSizeSplitter(
    # optionally, configure chunk_size, chunk_overlap, and approximate flag
    chunk_size=300,
    chunk_overlap=200,
    approximate = False
)
chunks = await splitter.run(text=document.text)
print(chunks)
# Out:
# chunks=[TextChunk(text='Harry Potter and the Chamber of \nSecrets Full Book Summary\nHarry Potter and the Chamber of Secrets\xa0begins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns', index=0, metadata=None, uid='bae283cc-7cea-4b79-97c8-81f3dc84c19d'), TextChunk(text='egins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous y', index=1, metadata=None, uid='3aecc141-c6c4-4871-a675-a7bb4133d9a2'), TextChunk(text='g a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the ', index=2, metadata=None, uid='4635820b-a752-490d-a0ec-3363af7709ec'), TextChunk(text=' Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHar', index=3, metadata=None, uid='129ce074-d670-4bf9-aa6c-5d219559660d'), TextChunk(text="ear. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the", index=4, metadata=None, uid='0e1740fd-9703-46c0-8e90-117622b54039'), TextChunk(text="Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two un", index=5, metadata=None, uid='67b59c35-0894-491a-8a1b-22e04d1eb5bd'), TextChunk(text="ry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a pho", index=6, metadata=None, uid='1d070499-d815-4271-ba96-928506fb1cfa'), TextChunk(text=" summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemie", index=7, metadata=None, uid='8c1f5366-71cb-443e-aeeb-bd0dace13449'), TextChunk(text="fortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemies, who almost starts a fight with Mr. Weasley. As Harry prepares \nto return to Hogwarts, he finds th", index=8, metadata=None, uid='2c0551bf-0b8e-4d8f-8ca2-8c3a779b8e89'), TextChunk(text="to shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemies, who almost starts a fight with Mr. Weasley. As Harry prepares \nto return to Hogwarts, he finds that he and Ron are unable to enter the \nmagically invisible train platform, so they fly the Weasley c", index=9, metadata=None, uid='ffdf354f-7967-42bb-9634-b150ccf38235'), TextChunk(text='s, who almost starts a fight with Mr. Weasley. As Har ...

# %%
print(chunks.chunks[0].text)
# Out:
# Harry Potter and the Chamber of
# Secrets Full Book Summary
# Harry Potter and the Chamber of Secrets begins when Harry is spending a
# miserable summer with his only remaining family, the Dursleys. During a
# dinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-
# elf. Dobby warns

# %%
text_chunk_embedder = TextChunkEmbedder(embedder=OpenAIEmbeddings())
embed = await text_chunk_embedder.run(text_chunks=chunks)

# %%
print(embed)
# Out:
# chunks=[TextChunk(text='Harry Potter and the Chamber of \nSecrets Full Book Summary\nHarry Potter and the Chamber of Secrets\xa0begins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns', index=0, metadata={'embedding': [0.004410936962813139, -0.01922260783612728, -0.027209002524614334, -0.041839759796857834, -0.004808940924704075, 0.023919712752103806, -0.016262246295809746, -0.021867195144295692, -0.029103633016347885, -0.013209786266088486, 0.018222663551568985, 0.026932701468467712, -0.0013017363380640745, 0.014380773529410362, 0.014420244842767715, -0.008749510161578655, 0.02626168727874756, -0.012597978115081787, 0.006673968397080898, -0.036761097609996796, -0.006657521706074476, 0.0024686118122190237, -0.01565701700747013, -0.007039079442620277, 0.006677257362753153, -0.019564693793654442, 0.028182631358504295, -0.02965623326599598, 0.006634496618062258, 0.006476610898971558, 0.014143944717943668, 0.004299101419746876, -0.004529351368546486, -0.028603659942746162, -0.009736296720802784, -0.015091259963810444, -0.018288448452949524, -0.0032317268196493387, 0.023393426090478897, -0.012019063346087933, 0.03028777614235878, 0.00958498939871788, -0.016380662098526955, 0.008736352436244488, -0.030761433765292168, 0.006322014145553112, 0.008085072971880436, -0.02245926856994629, -0.029393089935183525, -0.00673646479845047, 0.021801410242915154, 0.037734728306531906, -0.01916997879743576, -0.019880464300513268, -0.016420133411884308, -0.007664044387638569, -0.0034570430871099234, 0.014762330800294876, 0.010696768760681152, -0.024709142744541168, 0.008387687616050243, -0.005838488694280386, -0.025288056582212448, -0.005019455682486296, 0.008992916904389858, 0.005644420627504587, -0.021669838577508926, -0.009874447248876095, -0.0027432674542069435, -0.0037465007044374943, 0.039234645664691925, 0.04336599260568619, 0.002072252333164215, -0.010775712318718433, 0.025380156934261322, -0.0094139464199543, -0.03541906923055649, -0.0062726750038564205, -0.022314539179205894, -0.009677089750766754, 0.03697161376476288, -0.016722748056054115, 0.0011701646726578474, -0.002346907975152135, 0.03097194992005825, 0.020827781409025192, 0.008196908980607986, 0.010861233808100224, -0.027314258739352226, -0.00797323789447546, -0.02072252333164215, 0.00809165183454752, -0.0035951933823525906, 0.0014801801880821586, -0.017867419868707657, 0.010124432854354382, -0.010065225884318352, 0.04878674075007439, -0.01378870103508234, -0.007940344512462616, 0.0021183022763580084, -0.01831476390361786, -0.025603828951716423, -0.008466631174087524, -0.024314427748322487, -0.007420636713504791, 0.010729662142693996, -0.02931414730846882, 0.02534068562090397, -0.013163736090064049, 0.0027366888243705034, 0.0035491432063281536, -0.010696768760681152, -0.025524886325001717, 0.007229858078062534, -0.011966435238718987, -0.004424094222486019, -0.014222887344658375, -0.007953502237796783, -0.007841666229069233, 0.008578467182815075, 0.03068249113857746, 0.011104641482234001, -0.017262190580368042, 0.017525333911180496, 0.021775096654891968, -0.013512400910258293, -0.011104641482234001, 0.019669950008392334, -0.014288673177361488, 0.00869030226022005, 0.020933037623763084, 0.00339783588424325, -0.0028583924286067486, -0.05233917385339737, 0.03473489731550217, -0.010282319039106369, -0.007058815099298954, -0.017367448657751083, -0.034050725400447845, -0.0030672624707221985, 0.027051115408539772, -0.02931414730846882, -0.018354235216975212, 0.0035557218361645937, 0.013374250382184982, 0.026630086824297905, 0.02515648491680622, 0.011624348349869251, -0.013222943060100079, 0.028340516611933708, -0.000932513561565429, -0.0002939802361652255, 0.0010994449257850647, 0.019485751166939735, 0.004966827109456062, 0.005229969974607229, 0.012453249655663967, -0.02476176992058754, -0.024551255628466606, -0.0019768630154430866, 0.021367223 ...

# %%
chunk = embed.chunks[0]
text = chunk.text
embedding = chunk.metadata['embedding']
print("Text:", text[:100], "...")
print("\n\n")
print("Embedding (first 5 dims):", embedding[:5])
# Out:
# Text: Harry Potter and the Chamber of
# Secrets Full Book Summary
# Harry Potter and the Chamber of Secrets b ...
#
#
#
# Embedding (first 5 dims): [0.004410936962813139, -0.01922260783612728, -0.027209002524614334, -0.041839759796857834, -0.004808940924704075]

# %%
# config = LexicalGraphConfig()  # you can customize node labels or relationship names here

config = LexicalGraphConfig(
    chunk_node_label="Chunk123",
    document_node_label="Document123",
    chunk_to_document_relationship_type="PART_OF_DOCUMENT",
    next_chunk_relationship_type="NEXT_CHUNK",
    node_to_chunk_relationship_type="PART_OF_CHUNK",
    chunk_embedding_property="embeddings",
)

# %%
lex_builder = LexicalGraphBuilder(config=config)

graph_result = await lex_builder.run(
    text_chunks=chunks,
    document_info=DocumentInfo(path="HarryPotter.pdf")
)

# %%
neo4j_graph = graph_result.graph

# %%
print(neo4j_graph)
# Out:
# nodes=[Neo4jNode(id='359aa643-a4d8-4693-a179-5668cc9c6af3', label='Document123', properties={'path': 'HarryPotter.pdf', 'createdAt': '2025-05-02T12:57:36.341526+00:00'}, embedding_properties=None), Neo4jNode(id='bae283cc-7cea-4b79-97c8-81f3dc84c19d', label='Chunk123', properties={'text': 'Harry Potter and the Chamber of \nSecrets Full Book Summary\nHarry Potter and the Chamber of Secrets\xa0begins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns', 'index': 0}, embedding_properties={}), Neo4jNode(id='3aecc141-c6c4-4871-a675-a7bb4133d9a2', label='Chunk123', properties={'text': 'egins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous y', 'index': 1}, embedding_properties={}), Neo4jNode(id='4635820b-a752-490d-a0ec-3363af7709ec', label='Chunk123', properties={'text': 'g a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the ', 'index': 2}, embedding_properties={}), Neo4jNode(id='129ce074-d670-4bf9-aa6c-5d219559660d', label='Chunk123', properties={'text': ' Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHar', 'index': 3}, embedding_properties={}), Neo4jNode(id='0e1740fd-9703-46c0-8e90-117622b54039', label='Chunk123', properties={'text': "ear. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the", 'index': 4}, embedding_properties={}), Neo4jNode(id='67b59c35-0894-491a-8a1b-22e04d1eb5bd', label='Chunk123', properties={'text': "Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two un", 'index': 5}, embedding_properties={}), Neo4jNode(id='1d070499-d815-4271-ba96-928506fb1cfa', label='Chunk123', properties={'text': "ry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a pho", 'index': 6}, embedding_properties={}), Neo4jNode(id='8c1f5366-71cb-443e-aeeb-bd0dace13449', label='Chunk123', properties={'text': " summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemie", 'index': 7}, embedding_properties={}), Neo4jNode(id='2c0551bf-0b8e-4d8f-8ca2-8c3a779b8e89', label='Chunk123', properties={'text': "fortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemie ...

# %%
with neo4j.GraphDatabase.driver(
    "neo4j+ssc://.databases.neo4j.io", auth=("neo4j", "")
) as driver:
    writer = Neo4jWriter(driver)
    await writer.run(neo4j_graph)

# %%
config = LexicalGraphConfig(
    chunk_node_label="Chunk123",
    document_node_label="Document123",
    chunk_to_document_relationship_type="PART_OF_DOCUMENT",
    next_chunk_relationship_type="NEXT_CHUNK",
    node_to_chunk_relationship_type="PART_OF_CHUNK",
    chunk_embedding_property="embeddings",
)
driver = neo4j.GraphDatabase.driver(
    "neo4j+ssc://.databases.neo4j.io", auth=("neo4j", "")
)
reader = Neo4jChunkReader(driver)
result = await reader.run(lexical_graph_config=config)

# %%
result
# Out:
# TextChunks(chunks=[TextChunk(text='Harry Potter and the Chamber of \nSecrets Full Book Summary\nHarry Potter and the Chamber of Secrets\xa0begins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns', index=0, metadata={'embeddings': None}, uid='8cb4fa13-e1fa-4ec8-9e58-d3ffb74c1d4a'), TextChunk(text='egins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous y', index=1, metadata={'embeddings': None}, uid='b334325d-a7d7-454a-a580-e1915fec367b'), TextChunk(text='g a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the ', index=2, metadata={'embeddings': None}, uid='75596f09-cd5c-4c25-8f6d-be70cd06de32'), TextChunk(text=' Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHar', index=3, metadata={'embeddings': None}, uid='e660c6f7-8c4c-48ec-85b4-838d30c7c487'), TextChunk(text="ear. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the", index=4, metadata={'embeddings': None}, uid='cc186874-da45-4018-9905-4b409df96dc7'), TextChunk(text="Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two un", index=5, metadata={'embeddings': None}, uid='8ead9473-9407-4472-a07b-7a11682c6e5f'), TextChunk(text="ry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a pho", index=6, metadata={'embeddings': None}, uid='918f7aa2-945e-4b2b-a86f-ebbcd6e0dd7f'), TextChunk(text=" summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemie", index=7, metadata={'embeddings': None}, uid='ed620508-41f0-4093-833f-957f9226739c'), TextChunk(text="fortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemies, who almost starts a fight with Mr. Weasley. As Harry prepares \nto return to Hogwarts, he finds th", index=8, metadata={'embeddings': None}, uid='36eec627-50cc-47c2-b47f-454bfb132ace'), TextChunk(text="to shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemies, who almost starts a fight with Mr. Weasley. As Harry prepares \nto return to Hogwarts, he finds that he and Ron are unable to enter the \nmagically invisible train platform, so they fly ...

# %%
schema_builder = SchemaBuilder()
schema = await schema_builder.run(
    entities=[
        SchemaEntity(
            label="Person",
            properties=[
                SchemaProperty(name="name", type="STRING"),
                SchemaProperty(name="place_of_birth", type="STRING"),
                SchemaProperty(name="date_of_birth", type="DATE"),
            ],
        ),
        SchemaEntity(
            label="Organization",
            properties=[
                SchemaProperty(name="name", type="STRING"),
                SchemaProperty(name="country", type="STRING"),
            ],
        ),
        SchemaEntity(                              # ← NEW
            label="Field",
            properties=[
                SchemaProperty(name="name", type="STRING"),
            ],
        ),
    ],
    relations=[
        SchemaRelation(
            label="WORKED_ON",
        ),
        SchemaRelation(
            label="WORKED_FOR",
        ),
    ],
    potential_schema=[
        ("Person", "WORKED_ON", "Field"),
        ("Person", "WORKED_FOR", "Organization"),
    ],
)

# %%
schema
# Out:
# SchemaConfig(entities={'Person': {'label': 'Person', 'description': '', 'properties': [{'name': 'name', 'type': 'STRING', 'description': ''}, {'name': 'place_of_birth', 'type': 'STRING', 'description': ''}, {'name': 'date_of_birth', 'type': 'DATE', 'description': ''}]}, 'Organization': {'label': 'Organization', 'description': '', 'properties': [{'name': 'name', 'type': 'STRING', 'description': ''}, {'name': 'country', 'type': 'STRING', 'description': ''}]}, 'Field': {'label': 'Field', 'description': '', 'properties': [{'name': 'name', 'type': 'STRING', 'description': ''}]}}, relations={'WORKED_ON': {'label': 'WORKED_ON', 'description': '', 'properties': []}, 'WORKED_FOR': {'label': 'WORKED_FOR', 'description': '', 'properties': []}}, potential_schema=[('Person', 'WORKED_ON', 'Field'), ('Person', 'WORKED_FOR', 'Organization')])

# %%
extractor = LLMEntityRelationExtractor(
    llm=OpenAILLM(
        model_name="gpt-4o-mini",
        model_params={
            "max_tokens": 1000,
            "response_format": {"type": "json_object"},
        },
    )
)

# %%
neo4j_graph = await extractor.run(
    chunks=chunks,
)

# %%
neo4j_graph
# Out:
# Neo4jGraph(nodes=[Neo4jNode(id='8cb4fa13-e1fa-4ec8-9e58-d3ffb74c1d4a', label='Chunk', properties={'text': 'Harry Potter and the Chamber of \nSecrets Full Book Summary\nHarry Potter and the Chamber of Secrets\xa0begins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns', 'index': 0}, embedding_properties={}), Neo4jNode(id='b334325d-a7d7-454a-a580-e1915fec367b', label='Chunk', properties={'text': 'egins when Harry is spending a \nmiserable summer with his only remaining family, the Dursleys. During a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous y', 'index': 1}, embedding_properties={}), Neo4jNode(id='75596f09-cd5c-4c25-8f6d-be70cd06de32', label='Chunk', properties={'text': 'g a \ndinner party hosted by his uncle and aunt, Harry is visited by Dobby, a house-\nelf. Dobby warns Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the ', 'index': 2}, embedding_properties={}), Neo4jNode(id='e660c6f7-8c4c-48ec-85b4-838d30c7c487', label='Chunk', properties={'text': ' Harry not to return to Hogwarts, the magical school for \nwizards that Harry attended the previous year. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHar', 'index': 3}, embedding_properties={}), Neo4jNode(id='cc186874-da45-4018-9905-4b409df96dc7', label='Chunk', properties={'text': "ear. Harry politely disregards the \nwarning, and Dobby wreaks havoc in the kitchen, infuriating the Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the", 'index': 4}, embedding_properties={}), Neo4jNode(id='8ead9473-9407-4472-a07b-7a11682c6e5f', label='Chunk', properties={'text': "Dursleys. The \nDursleys angrily imprison Harry in his room for the rest of the summer. Luckily, \nHarry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two un", 'index': 5}, embedding_properties={}), Neo4jNode(id='918f7aa2-945e-4b2b-a86f-ebbcd6e0dd7f', label='Chunk', properties={'text': "ry's friend Ron Weasley steals Harry away in a flying car, and Harry happily \nspends the rest of the summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a pho", 'index': 6}, embedding_properties={}), Neo4jNode(id='ed620508-41f0-4093-833f-957f9226739c', label='Chunk', properties={'text': " summer at the Weasley home. While shopping for school \nsupplies with the Weasleys, Harry has two unfortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemie", 'index': 7}, embedding_properties={}), Neo4jNode(id='36eec627-50cc-47c2-b47f-454bfb132ace', label='Chunk', properties={'text': "fortunate encounters. He first \nencounters Lockhart, one of his teachers, who demands to be in a photo shoot \nwith Harry. Harry then encounters Lucius Malfoy, the evil father of one of \nHarry's enemies, who almost starts a fight with Mr. Weasley. As Harry prepares \nto return to Hogwarts, he finds th", 'index': 8}, embedding_properties={}), Neo4jNode(id='ff3c081f-51ec-47f5-823f-7f0a97257b7c', label='Chun ...
